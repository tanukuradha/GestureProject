# %% [markdown]
# # Gesture Recognition
# In this group project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly.

# %%
import numpy as np
import os
#from scipy.misc import  imresize
from skimage.transform import resize
import imageio
import datetime
import os
import abc
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
#tf.set_random_seed(30)
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('C:/Study/Gesture_Recognition/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('C:/Study/Gesture_Recognition/Project_data/val.csv').readlines())
batch_size = 8

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
project_folder='C:/Study/Gesture_Recognition/Project_data'

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=batch_size,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
   # Generator Function        
    def generator(self,source_path, folder_list, augment=False):
        # using np.linspace - it Return evenly spaced numbers over a specified interval.
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized= resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq="epoch")
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/Project_data/train'
val_path = 'Project_data/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs =20
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
#from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %% [markdown]
# ## Starting with small batch size 8

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=8,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 160, 160, 16   1312
#                              )
#
#  activation_4 (Activation)   (None, 30, 160, 160, 16   0
#                              )
#
#  batch_normalization_6 (Bat  (None, 30, 160, 160, 16   64
#  chNormalization)            )
#
#  max_pooling3d_4 (MaxPoolin  (None, 15, 80, 80, 16)    0
#  g3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 80, 80, 32)    4128
#
#  activation_5 (Activation)   (None, 15, 80, 80, 32)    0
#
#  batch_normalization_7 (Bat  (None, 15, 80, 80, 32)    128
#  chNormalization)
#
#  max_pooling3d_5 (MaxPoolin  (None, 7, 40, 40, 32)     0
#  g3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 40, 40, 64)     16448
#
#  activation_6 (Activation)   (None, 7, 40, 40, 64)     0
#
#  batch_normalization_8 (Bat  (None, 7, 40, 40, 64)     256
#  chNormalization)
#
#  max_pooling3d_6 (MaxPoolin  (None, 3, 20, 20, 64)     0
#  g3D)
#
#  conv3d_7 (Conv3D)           (None, 3, 20, 20, 128)    65664
#
#  activation_7 (Activation)   (None, 3, 20, 20, 128)    0
#
#  batch_normalization_9 (Bat  (None, 3, 20, 20, 128)    512
#  chNormalization)
#
#  max_pooling3d_7 (MaxPoolin  (None, 1, 10, 10, 128)    0
#  g3D)
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dense_3 (Dense)             (None, 128)               1638528
#
#  batch_normalization_10 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_11 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1736389 (6.62 MB)
# Trainable params: 1735525 (6.62 MB)
# Non-trainable params: 864 (3.38 KB)
# _________________________________________________________________

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = ModelConv3D1()
train_generator.initialize_path(project_folder)
train_generator.initialize_image_properties(image_height=160,image_width=160)
train_generator.initialize_hyperparams(frames_to_sample=30,batch_size=8,num_epochs=1)
gen = train_generator.generator(train_generator.val_path, train_generator.val_doc, augment=True) # self,source_path, folder_list, augment=False
batch_data,batch_label=next(gen)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])   
#val_generator = generator(val_path, val_doc, batch_size)

# %%
conv_3d1.train_model(conv_3d1_model)
# Out:
# 83/83 [==============================] - ETA: 0s - loss: 1.6289 - categorical_accuracy: 0.4103
# Epoch 1: val_loss improved from inf to 5.54652, saving model to model_init_2024-02-2612_29_23.883859\model-00001-1.62895-0.41026-5.54652-0.18000.h5
# 83/83 [==============================] - 150s 2s/step - loss: 1.6289 - categorical_accuracy: 0.4103 - val_loss: 5.5465 - val_categorical_accuracy: 0.1800 - lr: 0.0010

# %%
from sys import getsizeof

# %%
print("Memory util is {} Gigs". format(getsizeof(np.zeros((40,16,30,160,160)))/(1024*1024*1024)))
# Out:
# Memory util is 3.662109538912773 Gigs

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %% [markdown]
# ## Increasing the Batch Size to 16 and number of epochs to 10

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=16,num_epochs=10)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 30, 160, 160, 16   1312
#                              )
#
#  activation_12 (Activation)  (None, 30, 160, 160, 16   0
#                              )
#
#  batch_normalization_18 (Ba  (None, 30, 160, 160, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_12 (MaxPooli  (None, 15, 80, 80, 16)    0
#  ng3D)
#
#  conv3d_13 (Conv3D)          (None, 15, 80, 80, 32)    13856
#
#  activation_13 (Activation)  (None, 15, 80, 80, 32)    0
#
#  batch_normalization_19 (Ba  (None, 15, 80, 80, 32)    128
#  tchNormalization)
#
#  max_pooling3d_13 (MaxPooli  (None, 7, 40, 40, 32)     0
#  ng3D)
#
#  conv3d_14 (Conv3D)          (None, 7, 40, 40, 64)     55360
#
#  activation_14 (Activation)  (None, 7, 40, 40, 64)     0
#
#  batch_normalization_20 (Ba  (None, 7, 40, 40, 64)     256
#  tchNormalization)
#
#  max_pooling3d_14 (MaxPooli  (None, 3, 20, 20, 64)     0
#  ng3D)
#
#  conv3d_15 (Conv3D)          (None, 3, 20, 20, 128)    221312
#
#  activation_15 (Activation)  (None, 3, 20, 20, 128)    0
#
#  batch_normalization_21 (Ba  (None, 3, 20, 20, 128)    512
#  tchNormalization)
#
#  max_pooling3d_15 (MaxPooli  (None, 1, 10, 10, 128)    0
#  ng3D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_9 (Dense)             (None, 64)                819264
#
#  batch_normalization_22 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  batch_normalization_23 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1117061 (4.26 MB)
# Trainable params: 1116325 (4.26 MB)
# Non-trainable params: 736 (2.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# Epoch 1/10
# 42/42 [==============================] - ETA: 0s - loss: 1.5119 - categorical_accuracy: 0.4268
# Epoch 1: val_loss improved from inf to 2.80463, saving model to model_init_2024-02-2613_01_16.204180\model-00001-1.51193-0.42685-2.80463-0.16000.h5
# 42/42 [==============================] - 170s 4s/step - loss: 1.5119 - categorical_accuracy: 0.4268 - val_loss: 2.8046 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/10
# 42/42 [==============================] - ETA: 0s - loss: 0.9805 - categorical_accuracy: 0.6410
# Epoch 2: val_loss did not improve from 2.80463
# 42/42 [==============================] - 155s 4s/step - loss: 0.9805 - categorical_accuracy: 0.6410 - val_loss: 3.9959 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 3/10
# 42/42 [==============================] - ETA: 0s - loss: 0.6459 - categorical_accuracy: 0.7406
# Epoch 3: val_loss did not improve from 2.80463
# 42/42 [==============================] - 145s 4s/step - loss: 0.6459 - categorical_accuracy: 0.7406 - val_loss: 3.8866 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 4/10
# 42/42 [==============================] - ETA: 0s - loss: 0.4757 - categorical_accuracy: 0.8356
# Epoch 4: val_loss improved from 2.80463 to 2.62862, saving model to model_init_2024-02-2613_01_16.204180\model-00004-0.47567-0.83560-2.62862-0.27000.h5
# 42/42 [==============================] - 140s 3s/step - loss: 0.4757 - categorical_accuracy: 0.8356 - val_loss: 2.6286 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 5/10
# 42/42 [==============================] - ETA: 0s - loss: 0.3532 - categorical_accuracy: 0.8793
# Epoch 5: val_loss did not improve from 2.62862
# 42/42 [==============================] - 138s 3s/step - loss: 0.3532 - categorical_accuracy: 0.8793 - val_loss: 3.3638 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 6/10
# 42/42 [==============================] - ETA: 0s - loss: 0.4019 - categorical_accuracy: 0.8507
# Epoch 6: val_loss did not improve from 2.62862
# 42/42 [==============================] - 139s 3s/step - loss: 0.4019 - categorical_accuracy: 0.8507 - val_loss: 4.4395 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 7/10
# 42/42 [==============================] - ETA: 0s - loss: 0.2913 - categorical_accuracy: 0.8884
# Epoch 7: val_loss did not improve from 2.62862
# 42/42 [==============================] - 141s 3s/step - loss: 0.2913 - categorical_accuracy: 0.8884 - val_loss: 3.2635 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 8/10
# 42/42 [==============================] - ETA: 0s - loss: 0.2358 - categorical_accuracy: 0.9216
# Epoch 8: val_loss did not improve from 2.62862
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 42/42 [==============================] - 142s 3s/step - loss: 0.2358 - categorical_accuracy: 0.9216 - val_loss: 3.6805 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 9/10
# 42/42 [==============================] - ETA: 0s - loss: 0.1799 - categorical_accuracy: 0.9472
# Epoch 9: val_loss did not improve from 2.62862
# 42/42 [==============================] - 144s 3s/step - loss: 0.1799 - categorical_accuracy: 0.9472 - val_loss: 2.8757 - val_categorical_accuracy: 0.3300 - lr: 2.0000e-04
# Epoch 10/10
# 42/42 [==============================] - ETA: 0s - loss: 0.3648 - categorical_accuracy: 0.8763
# Epoch 10: val_loss improved from 2.62862 to 2.19680, saving model to model_init_2024-02-2613_01_16.204180\model-00010-0.36479-0.87632-2.19680-0.44000.h5
# 42/42 [==============================] - 141s 3s/step - loss: 0.3648 - categorical_accuracy: 0.8763 - val_loss: 2.1968 - val_categorical_accuracy: 0.4400 - lr: 2.0000e-04

# %%
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %%
plot(history_model1)

# %% [markdown]
# ## Model 2
# ## Adding dropout  and changing Batch Size to 32 and increasing No. of Epochs to 20

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=32,num_epochs=20)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_16 (Conv3D)          (None, 20, 160, 160, 16   1312
#                              )
#
#  activation_16 (Activation)  (None, 20, 160, 160, 16   0
#                              )
#
#  batch_normalization_24 (Ba  (None, 20, 160, 160, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_16 (MaxPooli  (None, 10, 80, 80, 16)    0
#  ng3D)
#
#  conv3d_17 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_17 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_25 (Ba  (None, 10, 80, 80, 32)    128
#  tchNormalization)
#
#  max_pooling3d_17 (MaxPooli  (None, 5, 40, 40, 32)     0
#  ng3D)
#
#  conv3d_18 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_18 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_26 (Ba  (None, 5, 40, 40, 64)     256
#  tchNormalization)
#
#  max_pooling3d_18 (MaxPooli  (None, 2, 20, 20, 64)     0
#  ng3D)
#
#  conv3d_19 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_19 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_27 (Ba  (None, 2, 20, 20, 128)    512
#  tchNormalization)
#
#  max_pooling3d_19 (MaxPooli  (None, 1, 10, 10, 128)    0
#  ng3D)
#
#  flatten_4 (Flatten)         (None, 12800)             0
#
#  dense_12 (Dense)            (None, 256)               3277056
#
#  batch_normalization_28 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  batch_normalization_29 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3638981 (13.88 MB)
# Trainable params: 3637477 (13.88 MB)
# Non-trainable params: 1504 (5.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# Epoch 1/20
# 21/21 [==============================] - ETA: 0s - loss: 1.8703 - categorical_accuracy: 0.4148
# Epoch 1: val_loss improved from inf to 1.94417, saving model to model_init_2024-02-2613_26_12.888263\model-00001-1.87032-0.41478-1.94417-0.28000.h5
# 21/21 [==============================] - 196s 9s/step - loss: 1.8703 - categorical_accuracy: 0.4148 - val_loss: 1.9442 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 2/20
# 21/21 [==============================] - ETA: 0s - loss: 1.2079 - categorical_accuracy: 0.5754
# Epoch 2: val_loss did not improve from 1.94417
# 21/21 [==============================] - 180s 9s/step - loss: 1.2079 - categorical_accuracy: 0.5754 - val_loss: 2.4573 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 3/20
# 21/21 [==============================] - ETA: 0s - loss: 0.9016 - categorical_accuracy: 0.6900
# Epoch 3: val_loss did not improve from 1.94417
# 21/21 [==============================] - 183s 9s/step - loss: 0.9016 - categorical_accuracy: 0.6900 - val_loss: 4.2391 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 4/20
# 21/21 [==============================] - ETA: 0s - loss: 0.6520 - categorical_accuracy: 0.7745
# Epoch 4: val_loss did not improve from 1.94417
# 21/21 [==============================] - 180s 9s/step - loss: 0.6520 - categorical_accuracy: 0.7745 - val_loss: 4.3129 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 5/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4913 - categorical_accuracy: 0.8318
# Epoch 5: val_loss did not improve from 1.94417
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 187s 9s/step - loss: 0.4913 - categorical_accuracy: 0.8318 - val_loss: 5.1174 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 6/20
# 21/21 [==============================] - ETA: 0s - loss: 0.3411 - categorical_accuracy: 0.8658
# Epoch 6: val_loss did not improve from 1.94417
# 21/21 [==============================] - 192s 9s/step - loss: 0.3411 - categorical_accuracy: 0.8658 - val_loss: 5.0970 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 7/20
# 21/21 [==============================] - ETA: 0s - loss: 0.2947 - categorical_accuracy: 0.8891
# Epoch 7: val_loss did not improve from 1.94417
# 21/21 [==============================] - 193s 9s/step - loss: 0.2947 - categorical_accuracy: 0.8891 - val_loss: 5.0228 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 8/20
# 21/21 [==============================] - ETA: 0s - loss: 0.2458 - categorical_accuracy: 0.9231
# Epoch 8: val_loss did not improve from 1.94417
# 21/21 [==============================] - 181s 9s/step - loss: 0.2458 - categorical_accuracy: 0.9231 - val_loss: 5.1777 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 9/20
# 21/21 [==============================] - ETA: 0s - loss: 0.2089 - categorical_accuracy: 0.9193
# Epoch 9: val_loss did not improve from 1.94417
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 185s 9s/step - loss: 0.2089 - categorical_accuracy: 0.9193 - val_loss: 4.7263 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 10/20
# 21/21 [==============================] - ETA: 0s - loss: 0.1899 - categorical_accuracy: 0.9351
# Epoch 10: val_loss did not improve from 1.94417
# 21/21 [==============================] - 188s 9s/step - loss: 0.1899 - categorical_accuracy: 0.9351 - val_loss: 4.5907 - val_categorical_accuracy: 0.2800 - lr: 4.0000e-05
# Epoch 11/20
# 21/21 [==============================] - ETA: 0s - loss: 0.1982 - categorical_accuracy: 0.9336
# Epoch 11: val_loss did not improve from 1.94417
# 21/21 [==============================] - 192s 9s/step - loss: 0.1982 - categorical_accuracy: 0.9336 - val_loss: 4.6930 - val_categorical_accuracy: 0.2600 - lr: 4.0000e-05
# Epoch 11: early stopping

# %%
plot(history_model2)

# %% [markdown]
# ##### We can see 1.94 val_loss did not improve from so earlystopping stops the epoch automatically!!
# - Last Epoch stop on 11/20!!
# - Best weights save automatically. The validation accuracy of 28% and training accuracy of 93%.

# %% [markdown]
# ## Model 3
# ### Optimizer used Adam with Learning rate
# ### Reduce filter size to (2,2,2) and image res to 120 x  120, - Batch Size = 30 and No. of Epochs = 25

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 16, 120, 120, 16   400
#                              )
#
#  activation_20 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_30 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_20 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_21 (Conv3D)          (None, 8, 60, 60, 32)     4128
#
#  activation_21 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_31 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_21 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_22 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_22 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_32 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_22 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_23 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_23 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_33 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_23 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_15 (Dense)            (None, 256)               1605888
#
#  batch_normalization_34 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  batch_normalization_35 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1762613 (6.72 MB)
# Trainable params: 1761109 (6.72 MB)
# Non-trainable params: 1504 (5.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# Epoch 1/25
# 23/23 [==============================] - ETA: 0s - loss: 2.0644 - categorical_accuracy: 0.3439
# Epoch 1: val_loss improved from inf to 1.76890, saving model to model_init_2024-02-2614_11_24.758070\model-00001-2.06438-0.34389-1.76890-0.21000.h5
# 23/23 [==============================] - 116s 5s/step - loss: 2.0644 - categorical_accuracy: 0.3439 - val_loss: 1.7689 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss: 1.3094 - categorical_accuracy: 0.5415
# Epoch 2: val_loss did not improve from 1.76890
# 23/23 [==============================] - 101s 5s/step - loss: 1.3094 - categorical_accuracy: 0.5415 - val_loss: 2.2320 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 3/25
# 23/23 [==============================] - ETA: 0s - loss: 1.0518 - categorical_accuracy: 0.6116
# Epoch 3: val_loss did not improve from 1.76890
# 23/23 [==============================] - 101s 5s/step - loss: 1.0518 - categorical_accuracy: 0.6116 - val_loss: 3.0130 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 4/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9213 - categorical_accuracy: 0.6735
# Epoch 4: val_loss did not improve from 1.76890
# 23/23 [==============================] - 98s 4s/step - loss: 0.9213 - categorical_accuracy: 0.6735 - val_loss: 4.1317 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 5/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8131 - categorical_accuracy: 0.6787
# Epoch 5: val_loss did not improve from 1.76890
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 23/23 [==============================] - 103s 5s/step - loss: 0.8131 - categorical_accuracy: 0.6787 - val_loss: 4.9665 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 6/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7747 - categorical_accuracy: 0.7210
# Epoch 6: val_loss did not improve from 1.76890
# 23/23 [==============================] - 99s 4s/step - loss: 0.7747 - categorical_accuracy: 0.7210 - val_loss: 5.9825 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 7/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7126 - categorical_accuracy: 0.7398
# Epoch 7: val_loss did not improve from 1.76890
# 23/23 [==============================] - 104s 5s/step - loss: 0.7126 - categorical_accuracy: 0.7398 - val_loss: 7.4157 - val_categorical_accuracy: 0.1400 - lr: 4.0000e-05
# Epoch 8/25
# 23/23 [==============================] - ETA: 0s - loss: 0.6965 - categorical_accuracy: 0.7443
# Epoch 8: val_loss did not improve from 1.76890
# 23/23 [==============================] - 101s 5s/step - loss: 0.6965 - categorical_accuracy: 0.7443 - val_loss: 7.8225 - val_categorical_accuracy: 0.2000 - lr: 4.0000e-05
# Epoch 9/25
# 23/23 [==============================] - ETA: 0s - loss: 0.6355 - categorical_accuracy: 0.7685
# Epoch 9: val_loss did not improve from 1.76890
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 23/23 [==============================] - 101s 5s/step - loss: 0.6355 - categorical_accuracy: 0.7685 - val_loss: 8.4777 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 10/25
# 23/23 [==============================] - ETA: 0s - loss: 0.6490 - categorical_accuracy: 0.7715
# Epoch 10: val_loss did not improve from 1.76890
# 23/23 [==============================] - 101s 5s/step - loss: 0.6490 - categorical_accuracy: 0.7715 - val_loss: 9.3652 - val_categorical_accuracy: 0.2000 - lr: 8.0000e-06
# Epoch 11/25
# 23/23 [==============================] - ETA: 0s - loss: 0.6248 - categorical_accuracy: 0.7700
# Epoch 11: val_loss did not improve from 1.76890
# 23/23 [==============================] - 99s 4s/step - loss: 0.6248 - categorical_accuracy: 0.7700 - val_loss: 8.9444 - val_categorical_accuracy: 0.2200 - lr: 8.0000e-06
# Epoch 11: early stopping

# %%
plot(history_model3)

# %% [markdown]
# ### Early stopping again and validation accuracy is low.. Overfitting issue

# %% [markdown]
# ## Model 4 -
# ### Adding more layers - Batch Size = 20 and optimizer is Adam without learning_rate

# %%
class ModelConv3D4(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4=ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d4_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_24 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_24 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_36 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  conv3d_25 (Conv3D)          (None, 16, 120, 120, 16   6928
#                              )
#
#  activation_25 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_37 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_24 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_26 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_26 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_38 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  conv3d_27 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_27 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_39 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_25 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_28 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_28 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_40 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  conv3d_29 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_29 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_41 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_26 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_30 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_30 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_42 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  conv3d_31 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_31 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_43 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_27 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_6 (Flatten)         (None, 6272)              0
#
#  dense_18 (Dense)            (None, 256)               1605888
#
#  batch_normalization_44 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_19 (Dense)            (None, 256)               65792
#
#  batch_normalization_45 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_20 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2556533 (9.75 MB)
# Trainable params: 2554549 (9.74 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 2556533
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.9632 - categorical_accuracy: 0.3899
# Epoch 1: val_loss improved from inf to 2.41868, saving model to model_init_2024-02-2615_08_54.701636\model-00001-1.96316-0.38989-2.41868-0.32000.h5
# 34/34 [==============================] - 175s 5s/step - loss: 1.9632 - categorical_accuracy: 0.3899 - val_loss: 2.4187 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.5317 - categorical_accuracy: 0.4721
# Epoch 2: val_loss did not improve from 2.41868
# 34/34 [==============================] - 157s 5s/step - loss: 1.5317 - categorical_accuracy: 0.4721 - val_loss: 6.8385 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2565 - categorical_accuracy: 0.5611
# Epoch 3: val_loss did not improve from 2.41868
# 34/34 [==============================] - 161s 5s/step - loss: 1.2565 - categorical_accuracy: 0.5611 - val_loss: 4.9782 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1933 - categorical_accuracy: 0.5882
# Epoch 4: val_loss did not improve from 2.41868
# 34/34 [==============================] - 160s 5s/step - loss: 1.1933 - categorical_accuracy: 0.5882 - val_loss: 5.0121 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0928 - categorical_accuracy: 0.6056
# Epoch 5: val_loss did not improve from 2.41868
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 154s 5s/step - loss: 1.0928 - categorical_accuracy: 0.6056 - val_loss: 3.0439 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7713 - categorical_accuracy: 0.7021
# Epoch 6: val_loss did not improve from 2.41868
# 34/34 [==============================] - 155s 5s/step - loss: 0.7713 - categorical_accuracy: 0.7021 - val_loss: 3.2711 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6947 - categorical_accuracy: 0.7406
# Epoch 7: val_loss did not improve from 2.41868
# 34/34 [==============================] - 155s 5s/step - loss: 0.6947 - categorical_accuracy: 0.7406 - val_loss: 3.6928 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5949 - categorical_accuracy: 0.7821
# Epoch 8: val_loss did not improve from 2.41868
# 34/34 [==============================] - 158s 5s/step - loss: 0.5949 - categorical_accuracy: 0.7821 - val_loss: 3.7895 - val_categorical_accuracy: 0.3300 - lr: 2.0000e-04
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5611 - categorical_accuracy: 0.7911
# Epoch 9: val_loss did not improve from 2.41868
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 156s 5s/step - loss: 0.5611 - categorical_accuracy: 0.7911 - val_loss: 2.9918 - val_categorical_accuracy: 0.2900 - lr: 2.0000e-04
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4612 - categorical_accuracy: 0.8333
# Epoch 10: val_loss did not improve from 2.41868
# 34/34 [==============================] - 159s 5s/step - loss: 0.4612 - categorical_accuracy: 0.8333 - val_loss: 2.8565 - val_categorical_accuracy: 0.3700 - lr: 4.0000e-05
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.4523 - categorical_accuracy: 0.8318
# Epoch 11: val_loss did not improve from 2.41868
# 34/34 [==============================] - 158s 5s/step - loss: 0.4523 - categorical_accuracy: 0.8318 - val_loss: 2.4414 - val_categorical_accuracy: 0.4100 - lr: 4.0000e-05
# Epoch 11: early stopping

# %%
plot(history_model4)

# %% [markdown]
# ## Model 5
# ### Changing Optimizer from Adam to Adadelta
#
# ### Adding dropout at convolution layers

# %%
class ModelConv3D5(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adadelta()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d5=ModelConv3D5()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=120,image_width=120)
conv_3d5.initialize_hyperparams(frames_to_sample=16,batch_size=32,num_epochs=15)
conv_3d5_model=conv_3d5.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.25)
conv_3d5_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_48 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_48 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_66 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  conv3d_49 (Conv3D)          (None, 16, 120, 120, 16   6928
#                              )
#
#  activation_49 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_67 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_36 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  dropout_26 (Dropout)        (None, 8, 60, 60, 16)     0
#
#  conv3d_50 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_50 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_68 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  conv3d_51 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_51 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_69 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_37 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  dropout_27 (Dropout)        (None, 4, 30, 30, 32)     0
#
#  conv3d_52 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_52 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_70 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  conv3d_53 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_53 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_71 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_38 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  dropout_28 (Dropout)        (None, 2, 15, 15, 64)     0
#
#  conv3d_54 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_54 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_72 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  conv3d_55 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_55 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_73 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_39 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  dropout_29 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_9 (Flatten)         (None, 6272)              0
#
#  dense_27 (Dense)            (None, 256)               1605888
#
#  batch_normalization_74 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_30 (Dropout)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 256)               65792
#
#  batch_normalization_75 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_31 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2556533 (9.75 MB)
# Trainable params: 2554549 (9.74 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d5_model.count_params())
history_model5=conv_3d5.train_model(conv_3d5_model,augment_data=True)
# Out:
# Total Params: 2556533
# Epoch 1/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3891 - categorical_accuracy: 0.1908
# Epoch 1: val_loss improved from inf to 1.61297, saving model to model_init_2024-02-2615_51_06.154116\model-00001-2.38910-0.19080-1.61297-0.23000.h5
# 21/21 [==============================] - 162s 8s/step - loss: 2.3891 - categorical_accuracy: 0.1908 - val_loss: 1.6130 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3851 - categorical_accuracy: 0.2051
# Epoch 2: val_loss did not improve from 1.61297
# 21/21 [==============================] - 155s 8s/step - loss: 2.3851 - categorical_accuracy: 0.2051 - val_loss: 1.6163 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 3/15
# 21/21 [==============================] - ETA: 0s - loss: 2.4441 - categorical_accuracy: 0.1983
# Epoch 3: val_loss did not improve from 1.61297
# 21/21 [==============================] - 160s 8s/step - loss: 2.4441 - categorical_accuracy: 0.1983 - val_loss: 1.6945 - val_categorical_accuracy: 0.1300 - lr: 0.0010
# Epoch 4/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3589 - categorical_accuracy: 0.1998
# Epoch 4: val_loss did not improve from 1.61297
# 21/21 [==============================] - 159s 8s/step - loss: 2.3589 - categorical_accuracy: 0.1998 - val_loss: 1.6730 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 5/15
# 21/21 [==============================] - ETA: 0s - loss: 2.2818 - categorical_accuracy: 0.2051
# Epoch 5: val_loss did not improve from 1.61297
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 160s 8s/step - loss: 2.2818 - categorical_accuracy: 0.2051 - val_loss: 1.6918 - val_categorical_accuracy: 0.1100 - lr: 0.0010
# Epoch 6/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3924 - categorical_accuracy: 0.2097
# Epoch 6: val_loss did not improve from 1.61297
# 21/21 [==============================] - 159s 8s/step - loss: 2.3924 - categorical_accuracy: 0.2097 - val_loss: 1.7283 - val_categorical_accuracy: 0.1100 - lr: 2.0000e-04
# Epoch 7/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3682 - categorical_accuracy: 0.2217
# Epoch 7: val_loss did not improve from 1.61297
# 21/21 [==============================] - 162s 8s/step - loss: 2.3682 - categorical_accuracy: 0.2217 - val_loss: 1.7163 - val_categorical_accuracy: 0.1200 - lr: 2.0000e-04
# Epoch 8/15
# 21/21 [==============================] - ETA: 0s - loss: 2.2506 - categorical_accuracy: 0.2368
# Epoch 8: val_loss did not improve from 1.61297
# 21/21 [==============================] - 160s 8s/step - loss: 2.2506 - categorical_accuracy: 0.2368 - val_loss: 1.7552 - val_categorical_accuracy: 0.1400 - lr: 2.0000e-04
# Epoch 9/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3493 - categorical_accuracy: 0.2029
# Epoch 9: val_loss did not improve from 1.61297
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 160s 8s/step - loss: 2.3493 - categorical_accuracy: 0.2029 - val_loss: 1.8170 - val_categorical_accuracy: 0.1100 - lr: 2.0000e-04
# Epoch 10/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3399 - categorical_accuracy: 0.2134
# Epoch 10: val_loss did not improve from 1.61297
# 21/21 [==============================] - 170s 8s/step - loss: 2.3399 - categorical_accuracy: 0.2134 - val_loss: 1.8875 - val_categorical_accuracy: 0.0800 - lr: 4.0000e-05
# Epoch 11/15
# 21/21 [==============================] - ETA: 0s - loss: 2.3568 - categorical_accuracy: 0.2036
# Epoch 11: val_loss did not improve from 1.61297
# 21/21 [==============================] - 162s 8s/step - loss: 2.3568 - categorical_accuracy: 0.2036 - val_loss: 1.9778 - val_categorical_accuracy: 0.1500 - lr: 4.0000e-05
# Epoch 11: early stopping

# %%
plot(history_model5)

# %% [markdown]
# ## Model 6
# ### Reducing the number of parameters

# %%
class ModelConv3D6(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d6=ModelConv3D6()
conv_3d6.initialize_path(project_folder)
conv_3d6.initialize_image_properties(image_height=100,image_width=100)
conv_3d6.initialize_hyperparams(frames_to_sample=16,batch_size=32,num_epochs=20)
conv_3d6_model=conv_3d6.define_model(dense_neurons=128,dropout=0.25)
conv_3d6_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_56 (Conv3D)          (None, 16, 100, 100, 16   1312
#                              )
#
#  activation_56 (Activation)  (None, 16, 100, 100, 16   0
#                              )
#
#  batch_normalization_76 (Ba  (None, 16, 100, 100, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_40 (MaxPooli  (None, 8, 50, 50, 16)     0
#  ng3D)
#
#  conv3d_57 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_57 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_77 (Ba  (None, 8, 50, 50, 32)     128
#  tchNormalization)
#
#  max_pooling3d_41 (MaxPooli  (None, 4, 25, 25, 32)     0
#  ng3D)
#
#  conv3d_58 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_58 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_78 (Ba  (None, 4, 25, 25, 64)     256
#  tchNormalization)
#
#  max_pooling3d_42 (MaxPooli  (None, 2, 12, 12, 64)     0
#  ng3D)
#
#  conv3d_59 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  activation_59 (Activation)  (None, 2, 12, 12, 128)    0
#
#  batch_normalization_79 (Ba  (None, 2, 12, 12, 128)    512
#  tchNormalization)
#
#  max_pooling3d_43 (MaxPooli  (None, 1, 6, 6, 128)      0
#  ng3D)
#
#  flatten_10 (Flatten)        (None, 4608)              0
#
#  dense_30 (Dense)            (None, 128)               589952
#
#  batch_normalization_80 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_32 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 128)               16512
#
#  batch_normalization_81 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_33 (Dropout)        (None, 128)               0
#
#  dense_32 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 696645 (2.66 MB)
# Trainable params: 695653 (2.65 MB)
# Non-trainable params: 992 (3.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d6_model.count_params())
history_model6=conv_3d6.train_model(conv_3d6_model,augment_data=True)
# Out:
# Total Params: 696645
# Epoch 1/20
# 21/21 [==============================] - ETA: 0s - loss: 1.7560 - categorical_accuracy: 0.3590
# Epoch 1: val_loss improved from inf to 1.67559, saving model to model_init_2024-02-2616_26_08.517242\model-00001-1.75596-0.35897-1.67559-0.21000.h5
# 21/21 [==============================] - 96s 5s/step - loss: 1.7560 - categorical_accuracy: 0.3590 - val_loss: 1.6756 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/20
# 21/21 [==============================] - ETA: 0s - loss: 1.1353 - categorical_accuracy: 0.5520
# Epoch 2: val_loss did not improve from 1.67559
# 21/21 [==============================] - 87s 4s/step - loss: 1.1353 - categorical_accuracy: 0.5520 - val_loss: 2.0557 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 3/20
# 21/21 [==============================] - ETA: 0s - loss: 0.8823 - categorical_accuracy: 0.6704
# Epoch 3: val_loss did not improve from 1.67559
# 21/21 [==============================] - 88s 4s/step - loss: 0.8823 - categorical_accuracy: 0.6704 - val_loss: 2.7160 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 4/20
# 21/21 [==============================] - ETA: 0s - loss: 0.7030 - categorical_accuracy: 0.7323
# Epoch 4: val_loss did not improve from 1.67559
# 21/21 [==============================] - 84s 4s/step - loss: 0.7030 - categorical_accuracy: 0.7323 - val_loss: 3.1166 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 5/20
# 21/21 [==============================] - ETA: 0s - loss: 0.6280 - categorical_accuracy: 0.7707
# Epoch 5: val_loss did not improve from 1.67559
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 21/21 [==============================] - 89s 4s/step - loss: 0.6280 - categorical_accuracy: 0.7707 - val_loss: 3.5657 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 6/20
# 21/21 [==============================] - ETA: 0s - loss: 0.5523 - categorical_accuracy: 0.7964
# Epoch 6: val_loss did not improve from 1.67559
# 21/21 [==============================] - 87s 4s/step - loss: 0.5523 - categorical_accuracy: 0.7964 - val_loss: 3.9689 - val_categorical_accuracy: 0.2800 - lr: 4.0000e-05
# Epoch 7/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4865 - categorical_accuracy: 0.8220
# Epoch 7: val_loss did not improve from 1.67559
# 21/21 [==============================] - 89s 4s/step - loss: 0.4865 - categorical_accuracy: 0.8220 - val_loss: 4.0170 - val_categorical_accuracy: 0.2600 - lr: 4.0000e-05
# Epoch 8/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4546 - categorical_accuracy: 0.8394
# Epoch 8: val_loss did not improve from 1.67559
# 21/21 [==============================] - 85s 4s/step - loss: 0.4546 - categorical_accuracy: 0.8394 - val_loss: 4.4501 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 9/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4416 - categorical_accuracy: 0.8424
# Epoch 9: val_loss did not improve from 1.67559
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 21/21 [==============================] - 88s 4s/step - loss: 0.4416 - categorical_accuracy: 0.8424 - val_loss: 4.6849 - val_categorical_accuracy: 0.1700 - lr: 4.0000e-05
# Epoch 10/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4538 - categorical_accuracy: 0.8348
# Epoch 10: val_loss did not improve from 1.67559
# 21/21 [==============================] - 87s 4s/step - loss: 0.4538 - categorical_accuracy: 0.8348 - val_loss: 4.7408 - val_categorical_accuracy: 0.1800 - lr: 8.0000e-06
# Epoch 11/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4511 - categorical_accuracy: 0.8424
# Epoch 11: val_loss did not improve from 1.67559
# 21/21 [==============================] - 88s 4s/step - loss: 0.4511 - categorical_accuracy: 0.8424 - val_loss: 4.5512 - val_categorical_accuracy: 0.1600 - lr: 8.0000e-06
# Epoch 11: early stopping

# %%
plot(history_model6)

# %% [markdown]
# ## Overfitting increased, adding dropout has further reduced the validation accuracy

# %% [markdown]
# ### Model 7
# #### Batch Normalization , Changing Batch size to 64

# %%
class ModelConv3D7(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d7=ModelConv3D7()
conv_3d7.initialize_path(project_folder)
conv_3d7.initialize_image_properties(image_height=120,image_width=120)
conv_3d7.initialize_hyperparams(frames_to_sample=16,batch_size=64,num_epochs=25)
conv_3d7_model=conv_3d7.define_model(dense_neurons=64,dropout=0.25)
conv_3d7_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_60 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_60 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_82 (Ba  (None, 16, 120, 120, 16   64
#  tchNormalization)           )
#
#  max_pooling3d_44 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_61 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_61 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_83 (Ba  (None, 8, 60, 60, 32)     128
#  tchNormalization)
#
#  max_pooling3d_45 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_62 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_62 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_84 (Ba  (None, 4, 30, 30, 64)     256
#  tchNormalization)
#
#  max_pooling3d_46 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_63 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_63 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_85 (Ba  (None, 2, 15, 15, 128)    512
#  tchNormalization)
#
#  max_pooling3d_47 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_11 (Flatten)        (None, 6272)              0
#
#  dense_33 (Dense)            (None, 64)                401472
#
#  batch_normalization_86 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_34 (Dropout)        (None, 64)                0
#
#  dense_34 (Dense)            (None, 64)                4160
#
#  batch_normalization_87 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_35 (Dropout)        (None, 64)                0
#
#  dense_35 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 504709 (1.93 MB)
# Trainable params: 503973 (1.92 MB)
# Non-trainable params: 736 (2.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d7_model.count_params())
history_model7=conv_3d7.train_model(conv_3d7_model,augment_data=True)
# Out:
# Total Params: 504709
# Epoch 1/25
# 11/11 [==============================] - ETA: 0s - loss: 1.8279 - categorical_accuracy: 0.3439
# Epoch 1: val_loss improved from inf to 1.59624, saving model to model_init_2024-02-2618_10_54.291912\model-00001-1.82788-0.34389-1.59624-0.24000.h5
# 11/11 [==============================] - 112s 11s/step - loss: 1.8279 - categorical_accuracy: 0.3439 - val_loss: 1.5962 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 2/25
# 11/11 [==============================] - ETA: 0s - loss: 1.2062 - categorical_accuracy: 0.5558
# Epoch 2: val_loss did not improve from 1.59624
# 11/11 [==============================] - 99s 10s/step - loss: 1.2062 - categorical_accuracy: 0.5558 - val_loss: 1.6873 - val_categorical_accuracy: 0.1300 - lr: 2.0000e-04
# Epoch 3/25
# 11/11 [==============================] - ETA: 0s - loss: 0.9459 - categorical_accuracy: 0.6373
# Epoch 3: val_loss did not improve from 1.59624
# 11/11 [==============================] - 105s 10s/step - loss: 0.9459 - categorical_accuracy: 0.6373 - val_loss: 1.8051 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 4/25
# 11/11 [==============================] - ETA: 0s - loss: 0.8770 - categorical_accuracy: 0.6614
# Epoch 4: val_loss did not improve from 1.59624
# 11/11 [==============================] - 100s 10s/step - loss: 0.8770 - categorical_accuracy: 0.6614 - val_loss: 2.0647 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 5/25
# 11/11 [==============================] - ETA: 0s - loss: 0.7546 - categorical_accuracy: 0.7029
# Epoch 5: val_loss did not improve from 1.59624
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 11/11 [==============================] - 106s 10s/step - loss: 0.7546 - categorical_accuracy: 0.7029 - val_loss: 2.1785 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/25
# 11/11 [==============================] - ETA: 0s - loss: 0.6373 - categorical_accuracy: 0.7617
# Epoch 6: val_loss did not improve from 1.59624
# 11/11 [==============================] - 101s 10s/step - loss: 0.6373 - categorical_accuracy: 0.7617 - val_loss: 2.2333 - val_categorical_accuracy: 0.2000 - lr: 4.0000e-05
# Epoch 7/25
# 11/11 [==============================] - ETA: 0s - loss: 0.6060 - categorical_accuracy: 0.7851
# Epoch 7: val_loss did not improve from 1.59624
# 11/11 [==============================] - 104s 10s/step - loss: 0.6060 - categorical_accuracy: 0.7851 - val_loss: 2.5834 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 8/25
# 11/11 [==============================] - ETA: 0s - loss: 0.5763 - categorical_accuracy: 0.7934
# Epoch 8: val_loss did not improve from 1.59624
# 11/11 [==============================] - 102s 10s/step - loss: 0.5763 - categorical_accuracy: 0.7934 - val_loss: 2.7201 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 9/25
# 11/11 [==============================] - ETA: 0s - loss: 0.5639 - categorical_accuracy: 0.7949
# Epoch 9: val_loss did not improve from 1.59624
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 11/11 [==============================] - 104s 10s/step - loss: 0.5639 - categorical_accuracy: 0.7949 - val_loss: 2.9984 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 10/25
# 11/11 [==============================] - ETA: 0s - loss: 0.5594 - categorical_accuracy: 0.8017
# Epoch 10: val_loss did not improve from 1.59624
# 11/11 [==============================] - 100s 10s/step - loss: 0.5594 - categorical_accuracy: 0.8017 - val_loss: 3.3995 - val_categorical_accuracy: 0.1300 - lr: 8.0000e-06
# Epoch 11/25
# 11/11 [==============================] - ETA: 0s - loss: 0.5604 - categorical_accuracy: 0.7941
# Epoch 11: val_loss did not improve from 1.59624
# 11/11 [==============================] - 105s 10s/step - loss: 0.5604 - categorical_accuracy: 0.7941 - val_loss: 3.3900 - val_categorical_accuracy: 0.1600 - lr: 8.0000e-06
# Epoch 11: early stopping

# %%
plot(history_model7)

# %% [markdown]
# ### Overfitting case.
# - Accuracy : 0.79
# - Validation Accuracy : .24

# %% [markdown]
# ## Model 8 - RNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        #model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        #model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        #model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        #model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        #model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_83 (TimeD  (None, 18, 120, 120, 16   448
#  istributed)                 )
#
#  time_distributed_84 (TimeD  (None, 18, 60, 60, 16)    0
#  istributed)
#
#  time_distributed_85 (TimeD  (None, 18, 60, 60, 32)    4640
#  istributed)
#
#  time_distributed_86 (TimeD  (None, 18, 30, 30, 32)    0
#  istributed)
#
#  time_distributed_87 (TimeD  (None, 18, 30, 30, 64)    18496
#  istributed)
#
#  time_distributed_88 (TimeD  (None, 18, 15, 15, 64)    0
#  istributed)
#
#  time_distributed_89 (TimeD  (None, 18, 15, 15, 128)   73856
#  istributed)
#
#  time_distributed_90 (TimeD  (None, 18, 7, 7, 128)     0
#  istributed)
#
#  time_distributed_91 (TimeD  (None, 18, 7, 7, 256)     295168
#  istributed)
#
#  time_distributed_92 (TimeD  (None, 18, 3, 3, 256)     0
#  istributed)
#
#  time_distributed_93 (TimeD  (None, 18, 2, 2, 512)     524800
#  istributed)
#
#  time_distributed_94 (TimeD  (None, 18, 2, 2, 512)     2048
#  istributed)
#
#  time_distributed_95 (TimeD  (None, 18, 1, 1, 512)     0
#  istributed)
#
#  time_distributed_96 (TimeD  (None, 18, 512)           0
#  istributed)
#
#  lstm_5 (LSTM)               (None, 128)               328192
#
#  dropout_46 (Dropout)        (None, 128)               0
#
#  dense_46 (Dense)            (None, 128)               16512
#
#  dropout_47 (Dropout)        (None, 128)               0
#
#  dense_47 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1264805 (4.82 MB)
# Trainable params: 1263781 (4.82 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model8=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1264805
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4637 - categorical_accuracy: 0.3250
# Epoch 1: val_loss improved from inf to 1.83683, saving model to model_init_2024-02-2712_41_23.367102\model-00001-1.46369-0.32504-1.83683-0.19000.h5
# 34/34 [==============================] - 140s 4s/step - loss: 1.4637 - categorical_accuracy: 0.3250 - val_loss: 1.8368 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3519 - categorical_accuracy: 0.3891
# Epoch 2: val_loss improved from 1.83683 to 1.56921, saving model to model_init_2024-02-2712_41_23.367102\model-00002-1.35188-0.38914-1.56921-0.18000.h5
# 34/34 [==============================] - 119s 4s/step - loss: 1.3519 - categorical_accuracy: 0.3891 - val_loss: 1.5692 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.2114 - categorical_accuracy: 0.4653
# Epoch 3: val_loss did not improve from 1.56921
# 34/34 [==============================] - 115s 3s/step - loss: 1.2114 - categorical_accuracy: 0.4653 - val_loss: 1.8096 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0603 - categorical_accuracy: 0.5475
# Epoch 4: val_loss did not improve from 1.56921
# 34/34 [==============================] - 113s 3s/step - loss: 1.0603 - categorical_accuracy: 0.5475 - val_loss: 2.2074 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9575 - categorical_accuracy: 0.6154
# Epoch 5: val_loss improved from 1.56921 to 1.41856, saving model to model_init_2024-02-2712_41_23.367102\model-00005-0.95749-0.61538-1.41856-0.33000.h5
# 34/34 [==============================] - 114s 3s/step - loss: 0.9575 - categorical_accuracy: 0.6154 - val_loss: 1.4186 - val_categorical_accuracy: 0.3300 - lr: 0.0010
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8983 - categorical_accuracy: 0.6335
# Epoch 6: val_loss improved from 1.41856 to 1.41090, saving model to model_init_2024-02-2712_41_23.367102\model-00006-0.89826-0.63348-1.41090-0.38000.h5
# 34/34 [==============================] - 116s 3s/step - loss: 0.8983 - categorical_accuracy: 0.6335 - val_loss: 1.4109 - val_categorical_accuracy: 0.3800 - lr: 0.0010
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8474 - categorical_accuracy: 0.6554
# Epoch 7: val_loss did not improve from 1.41090
# 34/34 [==============================] - 114s 3s/step - loss: 0.8474 - categorical_accuracy: 0.6554 - val_loss: 1.9506 - val_categorical_accuracy: 0.3400 - lr: 0.0010
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7140 - categorical_accuracy: 0.7217
# Epoch 8: val_loss did not improve from 1.41090
# 34/34 [==============================] - 113s 3s/step - loss: 0.7140 - categorical_accuracy: 0.7217 - val_loss: 2.5357 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6937 - categorical_accuracy: 0.7376
# Epoch 9: val_loss did not improve from 1.41090
# 34/34 [==============================] - 114s 3s/step - loss: 0.6937 - categorical_accuracy: 0.7376 - val_loss: 1.8975 - val_categorical_accuracy: 0.4200 - lr: 0.0010
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6175 - categorical_accuracy: 0.7753
# Epoch 10: val_loss did not improve from 1.41090
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 119s 4s/step - loss: 0.6175 - categorical_accuracy: 0.7753 - val_loss: 1.8219 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4688 - categorical_accuracy: 0.8296
# Epoch 11: val_loss did not improve from 1.41090
# 34/34 [==============================] - 112s 3s/step - loss: 0.4688 - categorical_accuracy: 0.8296 - val_loss: 1.4933 - val_categorical_accuracy: 0.4900 - lr: 2.0000e-04
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3719 - categorical_accuracy: 0.8560
# Epoch 12: val_loss improved from 1.41090 to 0.69760, saving model to model_init_2024-02-2712_41_23.367102\model-00012-0.37193-0.85596-0.69760-0.75000.h5
# 34/34 [==============================] - 113s 3s/step - loss: 0.3719 - categorical_accuracy: 0.8560 - val_loss: 0.6976 - val_categorical_accuracy: 0.7500 - lr: 2.0000e-04
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3251 - categorical_accuracy: 0.8914
# Epoch 13: val_loss did not improve from 0.69760
# 34/34 [==============================] - 113s 3s/step - loss: 0.3251 - categorical_accuracy: 0.8914 - val_loss: 0.7625 - val_categorical_accuracy: 0.7700 - lr: 2.0000e-04
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3036 - categorical_accuracy: 0.8891
# Epoch 14: val_loss did not improve from 0.69760
# 34/34 [==============================] - 112s 3s/step - loss: 0.3036 - categorical_accuracy: 0.8891 - val_loss: 0.9380 - val_categorical_accuracy: 0.6400 - lr: 2.0000e-04
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2794 - categorical_accuracy: 0.9035
# Epoch 15: val_loss did not improve from 0.69760
# 34/34 [==============================] - 113s 3s/step - loss: 0.2794 - categorical_accuracy: 0.9035 - val_loss: 0.8946 - val_categorical_accuracy: 0.6500 - lr: 2.0000e-04
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2386 - categorical_accuracy: 0.9148
# Epoch 16: val_loss improved from 0.69760 to 0.52750, saving model to model_init_2024-02-2712_41_23.367102\model-00016-0.23859-0.91478-0.52750-0.80000.h5
# 34/34 [==============================] - 113s 3s/step - loss: 0.2386 - categorical_accuracy: 0.9148 - val_loss: 0.5275 - val_categorical_accuracy: 0.8000 - lr: 2.0000e-04
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2185 - categorical_accuracy: 0.9246
# Epoch 17: val_loss did not improve from 0.52750
# 34/34 [==============================] - 112s 3s/step - loss: 0.2185 - categorical_accuracy: 0.9246 - val_loss: 0.7907 - val_categorical_accuracy: 0.7100 - lr: 2.0000e-04
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1653 - categorical_accuracy: 0.9472
# Epoch 18: val_loss did not improve from 0.52750
# 34/34 [==============================] - 113s 3s/step - loss: 0.1653 - categorical_accuracy: 0.9472 - val_loss: 0.6034 - val_categorical_accuracy: 0.8200 - lr: 2.0000e-04
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1981 - categorical_accuracy: 0.9359
# Epoch 19: val_loss improved from 0.52750 to 0.47469, saving model to model_init_2024-02-2712_41_23.367102\model-00019-0.19806-0.93590-0.47469-0.79000.h5
# 34/34 [==============================] - 113s 3s/step - loss: 0.1981 - categorical_accuracy: 0.9359 - val_loss: 0.4747 - val_categorical_accuracy: 0.7900 - lr: 2.0000e-04
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2024 - categorical_accuracy: 0.9231
# Epoch 20: val_loss did not improve from 0.47469
# 34/34 [==============================] - 112s 3s/step - loss: 0.2024 - categorical_accuracy: 0.9231 - val_loss: 0.7425 - val_categorical_accuracy: 0.7000 - lr: 2.0000e-04

# %%
plot(history_model8)

# %% [markdown]
# ##### For CNN - LSTM model we get a best validation accuracy of of 94% and validation loss went down to .20

# %% [markdown]
# ## Apply data augmentation & see the model performance, this may help reduce the cases for overfitting.

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq="epoch")
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:])

# %% [markdown]
# ## Model 9 with Augmentation
# ### (3,3,3) Filter & 160x160 Image resolution

# %%
class ModelConv3D9(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d9=ModelConv3D9()
conv_3d9.initialize_path(project_folder)
conv_3d9.initialize_image_properties(image_height=160,image_width=160)
conv_3d9.initialize_hyperparams(frames_to_sample=20,batch_size=32,num_epochs=20)
conv_3d9_model=conv_3d9.define_model(dense_neurons=256,dropout=0.5)
conv_3d9_model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_68 (Conv3D)          (None, 20, 160, 160, 16   1312
#                              )
#
#  activation_68 (Activation)  (None, 20, 160, 160, 16   0
#                              )
#
#  batch_normalization_121 (B  (None, 20, 160, 160, 16   64
#  atchNormalization)          )
#
#  max_pooling3d_52 (MaxPooli  (None, 10, 80, 80, 16)    0
#  ng3D)
#
#  conv3d_69 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_69 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_122 (B  (None, 10, 80, 80, 32)    128
#  atchNormalization)
#
#  max_pooling3d_53 (MaxPooli  (None, 5, 40, 40, 32)     0
#  ng3D)
#
#  conv3d_70 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_70 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_123 (B  (None, 5, 40, 40, 64)     256
#  atchNormalization)
#
#  max_pooling3d_54 (MaxPooli  (None, 2, 20, 20, 64)     0
#  ng3D)
#
#  conv3d_71 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_71 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_124 (B  (None, 2, 20, 20, 128)    512
#  atchNormalization)
#
#  max_pooling3d_55 (MaxPooli  (None, 1, 10, 10, 128)    0
#  ng3D)
#
#  flatten_19 (Flatten)        (None, 12800)             0
#
#  dense_51 (Dense)            (None, 256)               3277056
#
#  batch_normalization_125 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_50 (Dropout)        (None, 256)               0
#
#  dense_52 (Dense)            (None, 256)               65792
#
#  batch_normalization_126 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_51 (Dropout)        (None, 256)               0
#
#  dense_53 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3638981 (13.88 MB)
# Trainable params: 3637477 (13.88 MB)
# Non-trainable params: 1504 (5.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d9_model.count_params())
history_model9=conv_3d9.train_model(conv_3d9_model,augment_data=True)
# Out:
# Total Params: 3638981
# Epoch 1/20
# 21/21 [==============================] - ETA: 0s - loss: 2.0723 - categorical_accuracy: 0.3326
# Epoch 1: saving model to model_init_2024-02-2713_39_11.715308\model-00001-2.07232-0.33258-2.12891-0.16000.h5
# 21/21 [==============================] - 236s 11s/step - loss: 2.0723 - categorical_accuracy: 0.3326 - val_loss: 2.1289 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/20
# 21/21 [==============================] - ETA: 0s - loss: 1.3952 - categorical_accuracy: 0.5068
# Epoch 2: saving model to model_init_2024-02-2713_39_11.715308\model-00002-1.39522-0.50679-3.97165-0.19000.h5
# 21/21 [==============================] - 184s 9s/step - loss: 1.3952 - categorical_accuracy: 0.5068 - val_loss: 3.9717 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 3/20
# 21/21 [==============================] - ETA: 0s - loss: 1.0523 - categorical_accuracy: 0.6312
# Epoch 3: saving model to model_init_2024-02-2713_39_11.715308\model-00003-1.05229-0.63122-5.02387-0.14000.h5
# 21/21 [==============================] - 187s 9s/step - loss: 1.0523 - categorical_accuracy: 0.6312 - val_loss: 5.0239 - val_categorical_accuracy: 0.1400 - lr: 2.0000e-04
# Epoch 4/20
# 21/21 [==============================] - ETA: 0s - loss: 0.7998 - categorical_accuracy: 0.7036
# Epoch 4: saving model to model_init_2024-02-2713_39_11.715308\model-00004-0.79983-0.70362-6.31810-0.16000.h5
# 21/21 [==============================] - 184s 9s/step - loss: 0.7998 - categorical_accuracy: 0.7036 - val_loss: 6.3181 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 5/20
# 21/21 [==============================] - ETA: 0s - loss: 0.6585 - categorical_accuracy: 0.7579
# Epoch 5: saving model to model_init_2024-02-2713_39_11.715308\model-00005-0.65851-0.75792-6.89688-0.16000.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 21/21 [==============================] - 191s 9s/step - loss: 0.6585 - categorical_accuracy: 0.7579 - val_loss: 6.8969 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/20
# 21/21 [==============================] - ETA: 0s - loss: 0.5374 - categorical_accuracy: 0.7986
# Epoch 6: saving model to model_init_2024-02-2713_39_11.715308\model-00006-0.53739-0.79864-7.55943-0.18000.h5
# 21/21 [==============================] - 186s 9s/step - loss: 0.5374 - categorical_accuracy: 0.7986 - val_loss: 7.5594 - val_categorical_accuracy: 0.1800 - lr: 4.0000e-05
# Epoch 7/20
# 21/21 [==============================] - ETA: 0s - loss: 0.5445 - categorical_accuracy: 0.7926
# Epoch 7: saving model to model_init_2024-02-2713_39_11.715308\model-00007-0.54454-0.79261-6.93948-0.19000.h5
# 21/21 [==============================] - 199s 10s/step - loss: 0.5445 - categorical_accuracy: 0.7926 - val_loss: 6.9395 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 8/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4718 - categorical_accuracy: 0.8311
# Epoch 8: saving model to model_init_2024-02-2713_39_11.715308\model-00008-0.47178-0.83107-7.37131-0.18000.h5
# 21/21 [==============================] - 186s 9s/step - loss: 0.4718 - categorical_accuracy: 0.8311 - val_loss: 7.3713 - val_categorical_accuracy: 0.1800 - lr: 4.0000e-05
# Epoch 9/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4645 - categorical_accuracy: 0.8303
# Epoch 9: saving model to model_init_2024-02-2713_39_11.715308\model-00009-0.46451-0.83032-7.03213-0.24000.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 21/21 [==============================] - 190s 9s/step - loss: 0.4645 - categorical_accuracy: 0.8303 - val_loss: 7.0321 - val_categorical_accuracy: 0.2400 - lr: 4.0000e-05
# Epoch 10/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4236 - categorical_accuracy: 0.8462
# Epoch 10: saving model to model_init_2024-02-2713_39_11.715308\model-00010-0.42360-0.84615-6.65110-0.25000.h5
# 21/21 [==============================] - 186s 9s/step - loss: 0.4236 - categorical_accuracy: 0.8462 - val_loss: 6.6511 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 11/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4189 - categorical_accuracy: 0.8514
# Epoch 11: saving model to model_init_2024-02-2713_39_11.715308\model-00011-0.41887-0.85143-6.53581-0.25000.h5
# 21/21 [==============================] - 183s 9s/step - loss: 0.4189 - categorical_accuracy: 0.8514 - val_loss: 6.5358 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 12/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4017 - categorical_accuracy: 0.8575
# Epoch 12: saving model to model_init_2024-02-2713_39_11.715308\model-00012-0.40174-0.85747-6.34731-0.23000.h5
# 21/21 [==============================] - 181s 9s/step - loss: 0.4017 - categorical_accuracy: 0.8575 - val_loss: 6.3473 - val_categorical_accuracy: 0.2300 - lr: 8.0000e-06
# Epoch 13/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4564 - categorical_accuracy: 0.8318
# Epoch 13: saving model to model_init_2024-02-2713_39_11.715308\model-00013-0.45642-0.83183-6.16673-0.23000.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.5999999959603884e-06.
# 21/21 [==============================] - 188s 9s/step - loss: 0.4564 - categorical_accuracy: 0.8318 - val_loss: 6.1667 - val_categorical_accuracy: 0.2300 - lr: 8.0000e-06
# Epoch 14/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4084 - categorical_accuracy: 0.8416
# Epoch 14: saving model to model_init_2024-02-2713_39_11.715308\model-00014-0.40843-0.84163-5.62968-0.22000.h5
# 21/21 [==============================] - 192s 9s/step - loss: 0.4084 - categorical_accuracy: 0.8416 - val_loss: 5.6297 - val_categorical_accuracy: 0.2200 - lr: 1.6000e-06
# Epoch 15/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4128 - categorical_accuracy: 0.8424
# Epoch 15: saving model to model_init_2024-02-2713_39_11.715308\model-00015-0.41278-0.84238-5.88121-0.18000.h5
# 21/21 [==============================] - 196s 10s/step - loss: 0.4128 - categorical_accuracy: 0.8424 - val_loss: 5.8812 - val_categorical_accuracy: 0.1800 - lr: 1.6000e-06
# Epoch 16/20
# 21/21 [==============================] - ETA: 0s - loss: 0.3891 - categorical_accuracy: 0.8658
# Epoch 16: saving model to model_init_2024-02-2713_39_11.715308\model-00016-0.38905-0.86576-5.35265-0.23000.h5
# 21/21 [==============================] - 183s 9s/step - loss: 0.3891 - categorical_accuracy: 0.8658 - val_loss: 5.3527 - val_categorical_accuracy: 0.2300 - lr: 1.6000e-06
# Epoch 17/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4404 - categorical_accuracy: 0.8416
# Epoch 17: saving model to model_init_2024-02-2713_39_11.715308\model-00017-0.44036-0.84163-4.78510-0.26000.h5
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.200000037395512e-07.
# 21/21 [==============================] - 187s 9s/step - loss: 0.4404 - categorical_accuracy: 0.8416 - val_loss: 4.7851 - val_categorical_accuracy: 0.2600 - lr: 1.6000e-06
# Epoch 18/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4077 - categorical_accuracy: 0.8529
# Epoch 18: saving model to model_init_2024-02-2713_39_11.715308\model-00018-0.40773-0.85294-4.46434-0.28000.h5
# 21/21 [==============================] - 187s 9s/step - loss: 0.4077 - categorical_accuracy: 0.8529 - val_loss: 4.4643 - val_categorical_accuracy: 0.2800 - lr: 3.2000e-07
# Epoch 19/20
# 21/21 [==============================] - ETA: 0s - loss: 0.4110 - categorical_accuracy: 0.8582
# Epoch 19: saving model to model_init_2024-02-2713_39_11.715308\model-00019-0.41099-0.85822-3.89630-0.28000.h5
# 21/21 [==============================] - 186s 9s/step - loss: 0.4110 - categorical_accuracy: 0.8582 - val_loss: 3.8963 - val_categorical_accuracy: 0.2800 - lr: 3.2000e-07
# Epoch 20/20
# 21/21 [==============================] - ETA: 0s - loss: 0.3965 - categorical_accuracy: 0.8590
# Epoch 20: saving model to model_init_2024-02-2713_39_11.715308\model-00020-0.39650-0.85897-3.50446-0.30000.h5
# 21/21 [==============================] - 183s 9s/step - loss: 0.3965 - categorical_accuracy: 0.8590 - val_loss: 3.5045 - val_categorical_accuracy: 0.3000 - lr: 3.2000e-07

# %%
plot(history_model9)

# %% [markdown]
# ## Model 10 with Augmentation
# ### (2,2,2) Filter  & 120x120 Image resolution

# %%
class ModelConv3D10(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d10=ModelConv3D10()
conv_3d10.initialize_path(project_folder)
conv_3d10.initialize_image_properties(image_height=120,image_width=120)
conv_3d10.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d10_model=conv_3d10.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d10_model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_72 (Conv3D)          (None, 16, 120, 120, 16   400
#                              )
#
#  activation_72 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_127 (B  (None, 16, 120, 120, 16   64
#  atchNormalization)          )
#
#  max_pooling3d_56 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_73 (Conv3D)          (None, 8, 60, 60, 32)     4128
#
#  activation_73 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_128 (B  (None, 8, 60, 60, 32)     128
#  atchNormalization)
#
#  max_pooling3d_57 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_74 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_74 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_129 (B  (None, 4, 30, 30, 64)     256
#  atchNormalization)
#
#  max_pooling3d_58 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_75 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_75 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_130 (B  (None, 2, 15, 15, 128)    512
#  atchNormalization)
#
#  max_pooling3d_59 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_20 (Flatten)        (None, 6272)              0
#
#  dense_54 (Dense)            (None, 256)               1605888
#
#  batch_normalization_131 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_52 (Dropout)        (None, 256)               0
#
#  dense_55 (Dense)            (None, 256)               65792
#
#  batch_normalization_132 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_53 (Dropout)        (None, 256)               0
#
#  dense_56 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1762613 (6.72 MB)
# Trainable params: 1761109 (6.72 MB)
# Non-trainable params: 1504 (5.88 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d10_model.count_params())
history_model10=conv_3d10.train_model(conv_3d10_model,augment_data=True)
# Out:
# Total Params: 1762613
# Epoch 1/25
# 23/23 [==============================] - ETA: 0s - loss: 2.1543 - categorical_accuracy: 0.3439
# Epoch 1: saving model to model_init_2024-02-2715_27_37.254615\model-00001-2.15431-0.34389-1.84439-0.21000.h5
# 23/23 [==============================] - 116s 5s/step - loss: 2.1543 - categorical_accuracy: 0.3439 - val_loss: 1.8444 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss: 1.4798 - categorical_accuracy: 0.4894
# Epoch 2: saving model to model_init_2024-02-2715_27_37.254615\model-00002-1.47979-0.48944-2.79727-0.21000.h5
# 23/23 [==============================] - 103s 5s/step - loss: 1.4798 - categorical_accuracy: 0.4894 - val_loss: 2.7973 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 3/25
# 23/23 [==============================] - ETA: 0s - loss: 1.1329 - categorical_accuracy: 0.5995
# Epoch 3: saving model to model_init_2024-02-2715_27_37.254615\model-00003-1.13293-0.59955-3.41325-0.20000.h5
# 23/23 [==============================] - 104s 5s/step - loss: 1.1329 - categorical_accuracy: 0.5995 - val_loss: 3.4132 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 4/25
# 23/23 [==============================] - ETA: 0s - loss: 1.0436 - categorical_accuracy: 0.6154
# Epoch 4: saving model to model_init_2024-02-2715_27_37.254615\model-00004-1.04358-0.61538-3.94743-0.20000.h5
# 23/23 [==============================] - 103s 5s/step - loss: 1.0436 - categorical_accuracy: 0.6154 - val_loss: 3.9474 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 5/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9684 - categorical_accuracy: 0.6486
# Epoch 5: saving model to model_init_2024-02-2715_27_37.254615\model-00005-0.96837-0.64857-4.64315-0.26000.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 23/23 [==============================] - 105s 5s/step - loss: 0.9684 - categorical_accuracy: 0.6486 - val_loss: 4.6432 - val_categorical_accuracy: 0.2600 - lr: 2.0000e-04
# Epoch 6/25
# 23/23 [==============================] - ETA: 0s - loss: 0.9230 - categorical_accuracy: 0.6599
# Epoch 6: saving model to model_init_2024-02-2715_27_37.254615\model-00006-0.92299-0.65988-5.09646-0.20000.h5
# 23/23 [==============================] - 104s 5s/step - loss: 0.9230 - categorical_accuracy: 0.6599 - val_loss: 5.0965 - val_categorical_accuracy: 0.2000 - lr: 4.0000e-05
# Epoch 7/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8209 - categorical_accuracy: 0.7036
# Epoch 7: saving model to model_init_2024-02-2715_27_37.254615\model-00007-0.82093-0.70362-4.89329-0.17000.h5
# 23/23 [==============================] - 107s 5s/step - loss: 0.8209 - categorical_accuracy: 0.7036 - val_loss: 4.8933 - val_categorical_accuracy: 0.1700 - lr: 4.0000e-05
# Epoch 8/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8449 - categorical_accuracy: 0.6780
# Epoch 8: saving model to model_init_2024-02-2715_27_37.254615\model-00008-0.84489-0.67798-5.17589-0.19000.h5
# 23/23 [==============================] - 102s 5s/step - loss: 0.8449 - categorical_accuracy: 0.6780 - val_loss: 5.1759 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 9/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8042 - categorical_accuracy: 0.7179
# Epoch 9: saving model to model_init_2024-02-2715_27_37.254615\model-00009-0.80420-0.71795-5.61987-0.18000.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 23/23 [==============================] - 106s 5s/step - loss: 0.8042 - categorical_accuracy: 0.7179 - val_loss: 5.6199 - val_categorical_accuracy: 0.1800 - lr: 4.0000e-05
# Epoch 10/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7698 - categorical_accuracy: 0.7195
# Epoch 10: saving model to model_init_2024-02-2715_27_37.254615\model-00010-0.76982-0.71946-5.11367-0.24000.h5
# 23/23 [==============================] - 103s 5s/step - loss: 0.7698 - categorical_accuracy: 0.7195 - val_loss: 5.1137 - val_categorical_accuracy: 0.2400 - lr: 8.0000e-06
# Epoch 11/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8288 - categorical_accuracy: 0.7029
# Epoch 11: saving model to model_init_2024-02-2715_27_37.254615\model-00011-0.82878-0.70287-6.12015-0.11000.h5
# 23/23 [==============================] - 103s 5s/step - loss: 0.8288 - categorical_accuracy: 0.7029 - val_loss: 6.1202 - val_categorical_accuracy: 0.1100 - lr: 8.0000e-06
# Epoch 12/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7637 - categorical_accuracy: 0.7172
# Epoch 12: saving model to model_init_2024-02-2715_27_37.254615\model-00012-0.76373-0.71719-6.55464-0.17000.h5
# 23/23 [==============================] - 102s 5s/step - loss: 0.7637 - categorical_accuracy: 0.7172 - val_loss: 6.5546 - val_categorical_accuracy: 0.1700 - lr: 8.0000e-06
# Epoch 13/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8014 - categorical_accuracy: 0.7051
# Epoch 13: saving model to model_init_2024-02-2715_27_37.254615\model-00013-0.80138-0.70513-6.20326-0.18000.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.5999999959603884e-06.
# 23/23 [==============================] - 107s 5s/step - loss: 0.8014 - categorical_accuracy: 0.7051 - val_loss: 6.2033 - val_categorical_accuracy: 0.1800 - lr: 8.0000e-06
# Epoch 14/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8072 - categorical_accuracy: 0.7059
# Epoch 14: saving model to model_init_2024-02-2715_27_37.254615\model-00014-0.80724-0.70588-6.10151-0.18000.h5
# 23/23 [==============================] - 104s 5s/step - loss: 0.8072 - categorical_accuracy: 0.7059 - val_loss: 6.1015 - val_categorical_accuracy: 0.1800 - lr: 1.6000e-06
# Epoch 15/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8125 - categorical_accuracy: 0.6991
# Epoch 15: saving model to model_init_2024-02-2715_27_37.254615\model-00015-0.81246-0.69910-5.67099-0.23000.h5
# 23/23 [==============================] - 103s 5s/step - loss: 0.8125 - categorical_accuracy: 0.6991 - val_loss: 5.6710 - val_categorical_accuracy: 0.2300 - lr: 1.6000e-06
# Epoch 16/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7864 - categorical_accuracy: 0.7044
# Epoch 16: saving model to model_init_2024-02-2715_27_37.254615\model-00016-0.78638-0.70437-5.16089-0.23000.h5
# 23/23 [==============================] - 102s 5s/step - loss: 0.7864 - categorical_accuracy: 0.7044 - val_loss: 5.1609 - val_categorical_accuracy: 0.2300 - lr: 1.6000e-06
# Epoch 17/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7855 - categorical_accuracy: 0.7172
# Epoch 17: saving model to model_init_2024-02-2715_27_37.254615\model-00017-0.78551-0.71719-4.83200-0.23000.h5
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.200000037395512e-07.
# 23/23 [==============================] - 105s 5s/step - loss: 0.7855 - categorical_accuracy: 0.7172 - val_loss: 4.8320 - val_categorical_accuracy: 0.2300 - lr: 1.6000e-06
# Epoch 18/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7566 - categorical_accuracy: 0.7255
# Epoch 18: saving model to model_init_2024-02-2715_27_37.254615\model-00018-0.75655-0.72549-4.17891-0.28000.h5
# 23/23 [==============================] - 105s 5s/step - loss: 0.7566 - categorical_accuracy: 0.7255 - val_loss: 4.1789 - val_categorical_accuracy: 0.2800 - lr: 3.2000e-07
# Epoch 19/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7763 - categorical_accuracy: 0.7323
# Epoch 19: saving model to model_init_2024-02-2715_27_37.254615\model-00019-0.77632-0.73228-4.00882-0.24000.h5
# 23/23 [==============================] - 105s 5s/step - loss: 0.7763 - categorical_accuracy: 0.7323 - val_loss: 4.0088 - val_categorical_accuracy: 0.2400 - lr: 3.2000e-07
# Epoch 20/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7721 - categorical_accuracy: 0.7232
# Epoch 20: saving model to model_init_2024-02-2715_27_37.254615\model-00020-0.77214-0.72323-3.40971-0.30000.h5
# 23/23 [==============================] - 101s 5s/step - loss: 0.7721 - categorical_accuracy: 0.7232 - val_loss: 3.4097 - val_categorical_accuracy: 0.3000 - lr: 3.2000e-07
# Epoch 21/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8158 - categorical_accuracy: 0.7081
# Epoch 21: saving model to model_init_2024-02-2715_27_37.254615\model-00021-0.81584-0.70814-2.73313-0.35000.h5
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.399999961104187e-08.
# 23/23 [==============================] - 105s 5s/step - loss: 0.8158 - categorical_accuracy: 0.7081 - val_loss: 2.7331 - val_categorical_accuracy: 0.3500 - lr: 3.2000e-07
# Epoch 22/25
# 23/23 [==============================] - ETA: 0s - loss: 0.6978 - categorical_accuracy: 0.7428
# Epoch 22: saving model to model_init_2024-02-2715_27_37.254615\model-00022-0.69781-0.74284-2.25986-0.38000.h5
# 23/23 [==============================] - 100s 5s/step - loss: 0.6978 - categorical_accuracy: 0.7428 - val_loss: 2.2599 - val_categorical_accuracy: 0.3800 - lr: 6.4000e-08
# Epoch 23/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8329 - categorical_accuracy: 0.7262
# Epoch 23: saving model to model_init_2024-02-2715_27_37.254615\model-00023-0.83292-0.72624-2.22689-0.41000.h5
# 23/23 [==============================] - 103s 5s/step - loss: 0.8329 - categorical_accuracy: 0.7262 - val_loss: 2.2269 - val_categorical_accuracy: 0.4100 - lr: 6.4000e-08
# Epoch 24/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7909 - categorical_accuracy: 0.6983
# Epoch 24: saving model to model_init_2024-02-2715_27_37.254615\model-00024-0.79087-0.69834-1.48699-0.54000.h5
# 23/23 [==============================] - 99s 4s/step - loss: 0.7909 - categorical_accuracy: 0.6983 - val_loss: 1.4870 - val_categorical_accuracy: 0.5400 - lr: 6.4000e-08
# Epoch 25/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7743 - categorical_accuracy: 0.7142
# Epoch 25: saving model to model_init_2024-02-2715_27_37.254615\model-00025-0.77427-0.71418-1.38100-0.56000.h5
# 23/23 [==============================] - 101s 5s/step - loss: 0.7743 - categorical_accuracy: 0.7142 - val_loss: 1.3810 - val_categorical_accuracy: 0.5600 - lr: 6.4000e-08

# %%
plot(history_model10)

# %% [markdown]
# ## Model 11 with Augmentation
# ### additional layers

# %%
class ModelConv3D11(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(learning_rate=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d11=ModelConv3D11()
conv_3d11.initialize_path(project_folder)
conv_3d11.initialize_image_properties(image_height=120,image_width=120)
conv_3d11.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d11_model=conv_3d11.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d11_model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_76 (Conv3D)          (None, 16, 120, 120, 16   1312
#                              )
#
#  activation_76 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_133 (B  (None, 16, 120, 120, 16   64
#  atchNormalization)          )
#
#  conv3d_77 (Conv3D)          (None, 16, 120, 120, 16   6928
#                              )
#
#  activation_77 (Activation)  (None, 16, 120, 120, 16   0
#                              )
#
#  batch_normalization_134 (B  (None, 16, 120, 120, 16   64
#  atchNormalization)          )
#
#  max_pooling3d_60 (MaxPooli  (None, 8, 60, 60, 16)     0
#  ng3D)
#
#  conv3d_78 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_78 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_135 (B  (None, 8, 60, 60, 32)     128
#  atchNormalization)
#
#  conv3d_79 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_79 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_136 (B  (None, 8, 60, 60, 32)     128
#  atchNormalization)
#
#  max_pooling3d_61 (MaxPooli  (None, 4, 30, 30, 32)     0
#  ng3D)
#
#  conv3d_80 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_80 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_137 (B  (None, 4, 30, 30, 64)     256
#  atchNormalization)
#
#  conv3d_81 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_81 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_138 (B  (None, 4, 30, 30, 64)     256
#  atchNormalization)
#
#  max_pooling3d_62 (MaxPooli  (None, 2, 15, 15, 64)     0
#  ng3D)
#
#  conv3d_82 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_82 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_139 (B  (None, 2, 15, 15, 128)    512
#  atchNormalization)
#
#  conv3d_83 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_83 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_140 (B  (None, 2, 15, 15, 128)    512
#  atchNormalization)
#
#  max_pooling3d_63 (MaxPooli  (None, 1, 7, 7, 128)      0
#  ng3D)
#
#  flatten_21 (Flatten)        (None, 6272)              0
#
#  dense_57 (Dense)            (None, 256)               1605888
#
#  batch_normalization_141 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_54 (Dropout)        (None, 256)               0
#
#  dense_58 (Dense)            (None, 256)               65792
#
#  batch_normalization_142 (B  (None, 256)               1024
#  atchNormalization)
#
#  dropout_55 (Dropout)        (None, 256)               0
#
#  dense_59 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2556533 (9.75 MB)
# Trainable params: 2554549 (9.74 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
print("Total Params:", conv_3d11_model.count_params())
history_model11=conv_3d11.train_model(conv_3d11_model,augment_data=True)
# Out:
# Total Params: 2556533
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 2.0587 - categorical_accuracy: 0.3235
# Epoch 1: saving model to model_init_2024-02-2716_25_34.865088\model-00001-2.05873-0.32353-2.42218-0.16000.h5
# 34/34 [==============================] - 163s 5s/step - loss: 2.0587 - categorical_accuracy: 0.3235 - val_loss: 2.4222 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.5871 - categorical_accuracy: 0.4585
# Epoch 2: saving model to model_init_2024-02-2716_25_34.865088\model-00002-1.58708-0.45852-3.71380-0.15000.h5
# 34/34 [==============================] - 158s 5s/step - loss: 1.5871 - categorical_accuracy: 0.4585 - val_loss: 3.7138 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.3296 - categorical_accuracy: 0.5377
# Epoch 3: saving model to model_init_2024-02-2716_25_34.865088\model-00003-1.32962-0.53771-5.16030-0.14000.h5
# 34/34 [==============================] - 164s 5s/step - loss: 1.3296 - categorical_accuracy: 0.5377 - val_loss: 5.1603 - val_categorical_accuracy: 0.1400 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1600 - categorical_accuracy: 0.5822
# Epoch 4: saving model to model_init_2024-02-2716_25_34.865088\model-00004-1.16000-0.58220-5.89138-0.20000.h5
# 34/34 [==============================] - 157s 5s/step - loss: 1.1600 - categorical_accuracy: 0.5822 - val_loss: 5.8914 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0890 - categorical_accuracy: 0.6109
# Epoch 5: saving model to model_init_2024-02-2716_25_34.865088\model-00005-1.08896-0.61086-6.91783-0.12000.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 155s 5s/step - loss: 1.0890 - categorical_accuracy: 0.6109 - val_loss: 6.9178 - val_categorical_accuracy: 0.1200 - lr: 2.0000e-04
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9613 - categorical_accuracy: 0.6569
# Epoch 6: saving model to model_init_2024-02-2716_25_34.865088\model-00006-0.96129-0.65686-6.54108-0.16000.h5
# 34/34 [==============================] - 155s 5s/step - loss: 0.9613 - categorical_accuracy: 0.6569 - val_loss: 6.5411 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8267 - categorical_accuracy: 0.7074
# Epoch 7: saving model to model_init_2024-02-2716_25_34.865088\model-00007-0.82671-0.70739-6.72939-0.12000.h5
# 34/34 [==============================] - 154s 5s/step - loss: 0.8267 - categorical_accuracy: 0.7074 - val_loss: 6.7294 - val_categorical_accuracy: 0.1200 - lr: 4.0000e-05
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7979 - categorical_accuracy: 0.7006
# Epoch 8: saving model to model_init_2024-02-2716_25_34.865088\model-00008-0.79789-0.70060-6.56882-0.19000.h5
# 34/34 [==============================] - 156s 5s/step - loss: 0.7979 - categorical_accuracy: 0.7006 - val_loss: 6.5688 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7377 - categorical_accuracy: 0.7210
# Epoch 9: saving model to model_init_2024-02-2716_25_34.865088\model-00009-0.73772-0.72097-6.30962-0.15000.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 159s 5s/step - loss: 0.7377 - categorical_accuracy: 0.7210 - val_loss: 6.3096 - val_categorical_accuracy: 0.1500 - lr: 4.0000e-05
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6264 - categorical_accuracy: 0.7541
# Epoch 10: saving model to model_init_2024-02-2716_25_34.865088\model-00010-0.62635-0.75415-5.54726-0.24000.h5
# 34/34 [==============================] - 160s 5s/step - loss: 0.6264 - categorical_accuracy: 0.7541 - val_loss: 5.5473 - val_categorical_accuracy: 0.2400 - lr: 8.0000e-06
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6821 - categorical_accuracy: 0.7436
# Epoch 11: saving model to model_init_2024-02-2716_25_34.865088\model-00011-0.68210-0.74359-5.04434-0.24000.h5
# 34/34 [==============================] - 158s 5s/step - loss: 0.6821 - categorical_accuracy: 0.7436 - val_loss: 5.0443 - val_categorical_accuracy: 0.2400 - lr: 8.0000e-06
# Epoch 12/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6894 - categorical_accuracy: 0.7383
# Epoch 12: saving model to model_init_2024-02-2716_25_34.865088\model-00012-0.68940-0.73831-4.57236-0.26000.h5
# 34/34 [==============================] - 154s 5s/step - loss: 0.6894 - categorical_accuracy: 0.7383 - val_loss: 4.5724 - val_categorical_accuracy: 0.2600 - lr: 8.0000e-06
# Epoch 13/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6316 - categorical_accuracy: 0.7707
# Epoch 13: saving model to model_init_2024-02-2716_25_34.865088\model-00013-0.63157-0.77074-3.73412-0.28000.h5
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.5999999959603884e-06.
# 34/34 [==============================] - 166s 5s/step - loss: 0.6316 - categorical_accuracy: 0.7707 - val_loss: 3.7341 - val_categorical_accuracy: 0.2800 - lr: 8.0000e-06
# Epoch 14/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6355 - categorical_accuracy: 0.7685
# Epoch 14: saving model to model_init_2024-02-2716_25_34.865088\model-00014-0.63545-0.76848-2.86942-0.33000.h5
# 34/34 [==============================] - 168s 5s/step - loss: 0.6355 - categorical_accuracy: 0.7685 - val_loss: 2.8694 - val_categorical_accuracy: 0.3300 - lr: 1.6000e-06
# Epoch 15/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6618 - categorical_accuracy: 0.7594
# Epoch 15: saving model to model_init_2024-02-2716_25_34.865088\model-00015-0.66175-0.75943-2.06492-0.42000.h5
# 34/34 [==============================] - 164s 5s/step - loss: 0.6618 - categorical_accuracy: 0.7594 - val_loss: 2.0649 - val_categorical_accuracy: 0.4200 - lr: 1.6000e-06
# Epoch 16/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6796 - categorical_accuracy: 0.7511
# Epoch 16: saving model to model_init_2024-02-2716_25_34.865088\model-00016-0.67964-0.75113-1.66933-0.50000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.6796 - categorical_accuracy: 0.7511 - val_loss: 1.6693 - val_categorical_accuracy: 0.5000 - lr: 1.6000e-06
# Epoch 17/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6636 - categorical_accuracy: 0.7685
# Epoch 17: saving model to model_init_2024-02-2716_25_34.865088\model-00017-0.66363-0.76848-1.26460-0.59000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.6636 - categorical_accuracy: 0.7685 - val_loss: 1.2646 - val_categorical_accuracy: 0.5900 - lr: 1.6000e-06
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6168 - categorical_accuracy: 0.7926
# Epoch 18: saving model to model_init_2024-02-2716_25_34.865088\model-00018-0.61677-0.79261-1.02188-0.64000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.6168 - categorical_accuracy: 0.7926 - val_loss: 1.0219 - val_categorical_accuracy: 0.6400 - lr: 1.6000e-06
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6485 - categorical_accuracy: 0.7564
# Epoch 19: saving model to model_init_2024-02-2716_25_34.865088\model-00019-0.64848-0.75641-0.93878-0.69000.h5
# 34/34 [==============================] - 164s 5s/step - loss: 0.6485 - categorical_accuracy: 0.7564 - val_loss: 0.9388 - val_categorical_accuracy: 0.6900 - lr: 1.6000e-06
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6815 - categorical_accuracy: 0.7602
# Epoch 20: saving model to model_init_2024-02-2716_25_34.865088\model-00020-0.68148-0.76018-0.80657-0.73000.h5
# 34/34 [==============================] - 164s 5s/step - loss: 0.6815 - categorical_accuracy: 0.7602 - val_loss: 0.8066 - val_categorical_accuracy: 0.7300 - lr: 1.6000e-06
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6110 - categorical_accuracy: 0.7798
# Epoch 21: saving model to model_init_2024-02-2716_25_34.865088\model-00021-0.61097-0.77979-0.68649-0.75000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.6110 - categorical_accuracy: 0.7798 - val_loss: 0.6865 - val_categorical_accuracy: 0.7500 - lr: 1.6000e-06
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5819 - categorical_accuracy: 0.7790
# Epoch 22: saving model to model_init_2024-02-2716_25_34.865088\model-00022-0.58188-0.77903-0.66598-0.77000.h5
# 34/34 [==============================] - 165s 5s/step - loss: 0.5819 - categorical_accuracy: 0.7790 - val_loss: 0.6660 - val_categorical_accuracy: 0.7700 - lr: 1.6000e-06
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6102 - categorical_accuracy: 0.7738
# Epoch 23: saving model to model_init_2024-02-2716_25_34.865088\model-00023-0.61017-0.77376-0.43653-0.87000.h5
# 34/34 [==============================] - 166s 5s/step - loss: 0.6102 - categorical_accuracy: 0.7738 - val_loss: 0.4365 - val_categorical_accuracy: 0.8700 - lr: 1.6000e-06
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6144 - categorical_accuracy: 0.7760
# Epoch 24: saving model to model_init_2024-02-2716_25_34.865088\model-00024-0.61445-0.77602-0.77177-0.75000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.6144 - categorical_accuracy: 0.7760 - val_loss: 0.7718 - val_categorical_accuracy: 0.7500 - lr: 1.6000e-06
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6274 - categorical_accuracy: 0.7700
# Epoch 25: saving model to model_init_2024-02-2716_25_34.865088\model-00025-0.62740-0.76998-0.59885-0.79000.h5
# 34/34 [==============================] - 167s 5s/step - loss: 0.6274 - categorical_accuracy: 0.7700 - val_loss: 0.5989 - val_categorical_accuracy: 0.7900 - lr: 1.6000e-06

# %%
plot(history_model11)

# %% [markdown]
# #### Total of 12 Experiments conducted, Below are the details
# ![image.png](attachment:7473cfaf-8861-4e57-aa0a-1bc4647693a0.png)![image.png](attachment:12150174-6bce-4da7-98b8-884619f1794a.png)

# %% [markdown]
# ### Final Model LSTM Model that provided Accuracy of 93.5% and Validation accuracy of 79%
